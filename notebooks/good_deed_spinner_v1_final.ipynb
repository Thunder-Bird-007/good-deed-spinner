# %% [markdown]
# # Good Deed Spinner
#
# A beginner-friendly halal Python project that gives random good deed tasks using a spin-based system.

# %% [markdown]
# ## Project Idea
#
# This project is inspired by random spin games, but instead of gambling or betting, it gives useful and meaningful tasks such as good deeds, study actions, and kindness challenges.

# %%
import random

# %%
SYMBOLS = ["🌙", "📘", "🤲", "⭐", "🕌"]

# %%
TASKS = [
    "Make dua for your parents.",
    "Read 5 lines of Qur'an.",
    "Say Astaghfirullah 33 times.",
    "Revise one important formula.",
    "Drink a glass of water.",
    "Help a family member with something small.",
    "Study with focus for 10 minutes.",
    "Clean a small part of your desk."
]

# %%
def spin_symbols():
    return [
        random.choice(SYMBOLS),
        random.choice(SYMBOLS),
        random.choice(SYMBOLS)
    ]

# %%
def get_random_task():
    return random.choice(TASKS)

# %%
def get_result(spin_result):
    a, b, c = spin_result
    if a==b==c:
        return 20, "Jackpot! You got three of the same symbol!"
    elif a==b or b==c or c==a:
        return 10, "Two of the same symbol! Not bad!"
    else:
        return 5, "No matches this time. But you still get a good deed task!"

# %%
total_score = 0

for round in range(3):
    print(f"\n--- Spin {round + 1} ---")

    spin_result = spin_symbols()
    score, msg = get_result(spin_result)
    task = get_random_task()

    print("Spinning...")
    print(" | ".join(spin_result))
    print(msg)
    print(f"Your score: {score}")
    print(f"Your good deed task: {task}")

    total_score += score

print(f"\n--- Game Over ---")
print(f"Total score: {total_score}")
# Out:
# --- Spin 1 ---
# Spinning...
# 📘 | 🤲 | 🌙
# No matches this time. But you still get a good deed task!
# Your score: 5
# Your good deed task: Read 5 lines of Qur'an.
#
# --- Spin 2 ---
# Spinning...
# 🤲 | 🤲 | 🤲
# Jackpot! You got three of the same symbol!
# Your score: 20
# Your good deed task: Help a family member with something small.
#
# --- Spin 3 ---
# Spinning...
# 🤲 | 🤲 | 🕌
# Two of the same symbol! Not bad!
# Your score: 10
# Your good deed task: Make dua for your parents.
#
# --- Game Over ---
# Total score: 35

# %%
import random

SYMBOLS = ["🌙", "📘", "🤲", "⭐", "🕌"]
TASKS = [
    "Make dua for your parents.",
    "Read 5 lines of Qur'an.",
    "Say Astaghfirullah 33 times.",
    "Revise one important formula.",
    "Drink a glass of water.",
    "Help a family member with something small.",
    "Study with focus for 10 minutes.",
    "Clean a small part of your desk."
]   

def spin_symbols():
    return [
        random.choice(SYMBOLS),
        random.choice(SYMBOLS),
        random.choice(SYMBOLS)
    ]

def get_random_task():
    return random.choice(TASKS)

def get_result(spin_result):
    a, b, c = spin_result
    if a==b==c:
        return 20, "Jackpot! You got three of the same symbol!"
    elif a==b or b==c or c==a:
        return 10, "Two of the same symbol! Not bad!"
    else:
        return 5, "No matches this time. But you still get a good deed task!"

def run_spin():
    spin_result = spin_symbols()
    score, msg = get_result(spin_result)
    task = get_random_task()

    print("Spinning...")
    print(" | ".join(spin_result))
    print(msg)
    print(f"Your score: {score}")
    print(f"Your good deed task: {task}")

    return score

total_score = 0
for round in range(3):
    print(f"\n--- Spin {round + 1} ---")
    total_score += run_spin()
print(f"\nTotal score: {total_score}")
# Out:
# --- Spin 1 ---
# Spinning...
# 📘 | 🕌 | 📘
# Two of the same symbol! Not bad!
# Your score: 10
# Your good deed task: Say Astaghfirullah 33 times.
#
# --- Spin 2 ---
# Spinning...
# 🤲 | 🌙 | 📘
# No matches this time. But you still get a good deed task!
# Your score: 5
# Your good deed task: Drink a glass of water.
#
# --- Spin 3 ---
# Spinning...
# ⭐ | 🌙 | 🕌
# No matches this time. But you still get a good deed task!
# Your score: 5
# Your good deed task: Make dua for your parents.
#
# Total score: 20
